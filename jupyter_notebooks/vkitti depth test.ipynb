# %%
import os
import glob

import cv2
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image
from scipy.ndimage.morphology import grey_closing

# %%
img_path = '/media/hpc-4_Raid/dsungatullina/vkitti-images-depth/15-deg-left/00000.png'

# %%
img = cv2.imread(img_path, cv2.IMREAD_ANYCOLOR | cv2.IMREAD_ANYDEPTH)

# %%
img
# Out:
# array([[65535, 65535, 65535, ...,   995,   993,   990],
#        [65535, 65535, 65535, ...,   995,   993,   991],
#        [65535, 65535, 65535, ...,   995,   993,   991],
#        ...,
#        [  808,   809,   810, ...,   355,   354,   354],
#        [  808,   809,   810, ...,   355,   354,   354],
#        [  808,   808,   809, ...,   355,   354,   354]], dtype=uint16)

# %%
depth = Image.open(img_path)

# %%
img.max(), img.min(), img.shape
# Out:
# (65535, 353, (375, 1242))

# %%
img = img / 100.0
img[img>50.0] = 50.0

# %%
plt.figure(figsize=(20,20))
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.imshow(img)
plt.show()
