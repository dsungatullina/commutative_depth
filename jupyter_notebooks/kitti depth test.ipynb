# %%
import os
import glob

import cv2
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image
from scipy.ndimage.morphology import grey_closing

# %%
img_path = '/media/hpc-4_Raid/dsungatullina/kitti-images-depth/depth_annotated/2011_09_26_drive_0001_sync/proj_depth/groundtruth/image_02/0000000005.png'

# %%
img = Image.open(img_path)

# %%
img_ar = np.array(img)

# %%
plt.figure(figsize=(20,20))
plt.imshow(img_ar)
plt.show()
